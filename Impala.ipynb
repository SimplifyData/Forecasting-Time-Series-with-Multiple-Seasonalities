# %%
import pandas as pd
import numpy as np

# %%
prod_df = pd.read_csv("Data/accumap_prod_data.csv")

# %%
prod_df.shape
# Out:
# (3863, 49)

# %%
prod_df.head()
# Out:
#        ©2018 IHS Markit   Production  \
# 0                 \nUWI  \nProd Date
# 1  100/06-20-033-04W5/0     Jan-2000
# 2  100/06-20-033-04W5/0     Feb-2000
# 3  100/06-20-033-04W5/0     Mar-2000
# 4  100/06-20-033-04W5/0     Apr-2000
#
#   List: Harvest - Caroline - Well List.lwell\nDatum: NAD83 (NTv2 - ATS 2.6 Grid)  \
# 0                                           \nStatus
# 1                                        FLOWING GAS
# 2                                        FLOWING GAS
# 3                                        FLOWING GAS
# 4                                        FLOWING GAS
#
#             Unnamed: 3             Unnamed: 4             Unnamed: 5  \
# 0  Monthly\nOil\n(bbl)  Avg Dly\nOil\n(bbl/d)  Cal Dly\nOil\n(bbl/d)
# 1                 0.00                   0.00                   0.00
# 2                 0.00                   0.00                   0.00
# 3                 0.00                   0.00                   0.00
# 4                 0.00                   0.00                   0.00
#
#             Unnamed: 6           Unnamed: 7             Unnamed: 8  \
# 0  Cum Prd\nOil\n(bbl)  Monthly\nGas\n(mcf)  Avg Dly\nGas\n(mcf/d)
# 1                 0.00            724753.57               23794.92
# 2                 0.00            723603.57               25389.60
# 3                 0.00            743476.51               24817.02
# 4                 0.00            616675.16               24916.17
#
#               Unnamed: 9        ...               Unnamed: 39  \
# 0  Cal Dly\nGas\n(mcf/d)        ...          Inj\nHours\n(hr)
# 1               23379.15        ...                         0
# 2               24951.85        ...                         0
# 3               23983.11        ...                         0
# 4               20555.84        ...                         0
#
#         Unnamed: 40           Unnamed: 41 Unnamed: 42 Unnamed: 43 Unnamed: 44  \
# 0  Prd\nHours\n(hr)  Inj/Prd\nHours\n(hr)  \nWCT\n(%)  \nOCT\n(%)  \nCCT\n(%)
# 1               731                   731      100.00        0.00        0.00
# 2               684                   684      100.00        0.00        0.00
# 3               719                   719      100.00        0.00        0.00
# 4               594                   594      100.00        0.00        0.00
#
#         Unnamed: 45        Unnamed: 46       Unnamed: 47        Unnamed: 48
# 0  \nGOR\n(scf/bbl)  \nWGR\n(bbl/mmcf)  \nWOR\n(bbl/bbl)  \nCGR\n(bbl/mmcf)
# 1              0.00               3.14              0.00               0.00
# 2              0.00               2.93              0.00               0.00
# 3              0.00               2.98              0.00               0.00
# 4              0.00               2.99              0.00               0.00
#
# [5 rows x 49 columns]

# %% [markdown]
# ### Fixing Columns
# ###### The column headings are incorrect

# %%
columns = prod_df.iloc[0].str.strip().str.lower().str.replace("\n","_").str.replace(" ","_").tolist()

# %% [markdown]
# ##### Features names created

# %%
columns
# Out:
# ['uwi',
#  'prod_date',
#  'status',
#  'monthly_oil_(bbl)',
#  'avg_dly_oil_(bbl/d)',
#  'cal_dly_oil_(bbl/d)',
#  'cum_prd_oil_(bbl)',
#  'monthly_gas_(mcf)',
#  'avg_dly_gas_(mcf/d)',
#  'cal_dly_gas_(mcf/d)',
#  'cum_prd_gas_(mcf)',
#  'monthly_water_(bbl)',
#  'avg_dly_water_(bbl/d)',
#  'cal_dly_water_(bbl/d)',
#  'cum_prd_water_(bbl)',
#  'monthly_cond_(bbl)',
#  'avg_dly_cond_(bbl/d)',
#  'cal_dly_cond_(bbl/d)',
#  'cum_prd_cond_(bbl)',
#  'monthly_fluid_(bbl)',
#  'avg_dly_fluid_(bbl/d)',
#  'cal_dly_fluid_(bbl/d)',
#  'cum_prd_fluid_(bbl)',
#  'mon_inj_oil_(bbl)',
#  'avg_inj_oil_(bbl/d)',
#  'cal_inj_oil_(bbl/d)',
#  'cum_inj_oil_(bbl)',
#  'mon_inj_gas_(mcf)',
#  'avg_inj_gas_(mcf/d)',
#  'cal_inj_gas_(mcf/d)',
#  'cum_inj_gas_(mcf)',
#  'mon_inj_water_(bbl)',
#  'avg_inj_water_(bbl/d)',
#  'cal_inj_water_(bbl/d)',
#  'cum_inj_water_(bbl)',
#  'mon_inj_solv_(mcf)',
#  'avg_inj_solv_(mcf/d)',
#  'cal_inj_solv_(mcf/d)',
#  'cum_inj_solv_(mcf)',
#  'inj_hours_(hr)',
#  'prd_hours_(hr)',
#  'inj/prd_hours_(hr)',
#  'wct_(%)',
#  'oct_(%)',
#  'cct_(%)',
#  'gor_(scf/bbl)',
#  'wgr_(bbl/mmcf)',
#  'wor_(bbl/bbl)',
#  'cgr_(bbl/mmcf)']

# %% [markdown]
# ### Replacing Feature names

# %%
df_col = {}

for i,col in enumerate(prod_df.columns):
    df_col[col] = columns[i]

prod_df = prod_df.rename(df_col, axis = "columns")

# %%
df_col
# Out:
# {'©2018 IHS Markit': 'uwi',
#  'Production': 'prod_date',
#  'List: Harvest - Caroline - Well List.lwell\nDatum: NAD83 (NTv2 - ATS 2.6 Grid)': 'status',
#  'Unnamed: 3': 'monthly_oil_(bbl)',
#  'Unnamed: 4': 'avg_dly_oil_(bbl/d)',
#  'Unnamed: 5': 'cal_dly_oil_(bbl/d)',
#  'Unnamed: 6': 'cum_prd_oil_(bbl)',
#  'Unnamed: 7': 'monthly_gas_(mcf)',
#  'Unnamed: 8': 'avg_dly_gas_(mcf/d)',
#  'Unnamed: 9': 'cal_dly_gas_(mcf/d)',
#  'Unnamed: 10': 'cum_prd_gas_(mcf)',
#  'Unnamed: 11': 'monthly_water_(bbl)',
#  'Unnamed: 12': 'avg_dly_water_(bbl/d)',
#  'Unnamed: 13': 'cal_dly_water_(bbl/d)',
#  'Unnamed: 14': 'cum_prd_water_(bbl)',
#  'Unnamed: 15': 'monthly_cond_(bbl)',
#  'Unnamed: 16': 'avg_dly_cond_(bbl/d)',
#  'Unnamed: 17': 'cal_dly_cond_(bbl/d)',
#  'Unnamed: 18': 'cum_prd_cond_(bbl)',
#  'Unnamed: 19': 'monthly_fluid_(bbl)',
#  'Unnamed: 20': 'avg_dly_fluid_(bbl/d)',
#  'Unnamed: 21': 'cal_dly_fluid_(bbl/d)',
#  'Unnamed: 22': 'cum_prd_fluid_(bbl)',
#  'Unnamed: 23': 'mon_inj_oil_(bbl)',
#  'Unnamed: 24': 'avg_inj_oil_(bbl/d)',
#  'Unnamed: 25': 'cal_inj_oil_(bbl/d)',
#  'Unnamed: 26': 'cum_inj_oil_(bbl)',
#  'Unnamed: 27': 'mon_inj_gas_(mcf)',
#  'Unnamed: 28': 'avg_inj_gas_(mcf/d)',
#  'Unnamed: 29': 'cal_inj_gas_(mcf/d)',
#  'Unnamed: 30': 'cum_inj_gas_(mcf)',
#  'Unnamed: 31': 'mon_inj_water_(bbl)',
#  'Unnamed: 32': 'avg_inj_water_(bbl/d)',
#  'Unnamed: 33': 'cal_inj_water_(bbl/d)',
#  'Unnamed: 34': 'cum_inj_water_(bbl)',
#  'Unnamed: 35': 'mon_inj_solv_(mcf)',
#  'Unnamed: 36': 'avg_inj_solv_(mcf/d)',
#  'Unnamed: 37': 'cal_inj_solv_(mcf/d)',
#  'Unnamed: 38': 'cum_inj_solv_(mcf)',
#  'Unnamed: 39': 'inj_hours_(hr)',
#  'Unnamed: 40': 'prd_hours_(hr)',
#  'Unnamed: 41': 'inj/prd_hours_(hr)',
#  'Unnamed: 42': 'wct_(%)',
#  'Unnamed: 43': 'oct_(%)',
#  'Unnamed: 44': 'cct_(%)',
#  'Unnamed: 45': 'gor_(scf/bbl)',
#  'Unnamed: 46': 'wgr_(bbl/mmcf)',
#  'Unnamed: 47': 'wor_(bbl/bbl)',
#  'Unnamed: 48': 'cgr_(bbl/mmcf)'}

# %% [markdown]
# ### Dropping columns names which was a row before

# %%
prod_df.drop(prod_df.index[0], inplace= True)

# %%
prod_df.head()
# Out:
#                     uwi prod_date       status monthly_oil_(bbl)  \
# 1  100/06-20-033-04W5/0  Jan-2000  FLOWING GAS              0.00
# 2  100/06-20-033-04W5/0  Feb-2000  FLOWING GAS              0.00
# 3  100/06-20-033-04W5/0  Mar-2000  FLOWING GAS              0.00
# 4  100/06-20-033-04W5/0  Apr-2000  FLOWING GAS              0.00
# 5  100/06-20-033-04W5/0  May-2000  FLOWING GAS              0.00
#
#   avg_dly_oil_(bbl/d) cal_dly_oil_(bbl/d) cum_prd_oil_(bbl) monthly_gas_(mcf)  \
# 1                0.00                0.00              0.00         724753.57
# 2                0.00                0.00              0.00         723603.57
# 3                0.00                0.00              0.00         743476.51
# 4                0.00                0.00              0.00         616675.16
# 5                0.00                0.00              0.00         739799.36
#
#   avg_dly_gas_(mcf/d) cal_dly_gas_(mcf/d)      ...       inj_hours_(hr)  \
# 1            23794.92            23379.15      ...                    0
# 2            25389.60            24951.85      ...                    0
# 3            24817.02            23983.11      ...                    0
# 4            24916.17            20555.84      ...                    0
# 5            24322.17            23864.50      ...                    0
#
#   prd_hours_(hr) inj/prd_hours_(hr) wct_(%) oct_(%) cct_(%) gor_(scf/bbl)  \
# 1            731                731  100.00    0.00    0.00          0.00
# 2            684                684  100.00    0.00    0.00          0.00
# 3            719                719  100.00    0.00    0.00          0.00
# 4            594                594  100.00    0.00    0.00          0.00
# 5            730                730  100.00    0.00    0.00          0.00
#
#   wgr_(bbl/mmcf) wor_(bbl/bbl) cgr_(bbl/mmcf)
# 1           3.14          0.00           0.00
# 2           2.93          0.00           0.00
# 3           2.98          0.00           0.00
# 4           2.99          0.00           0.00
# 5           3.07          0.00           0.00
#
# [5 rows x 49 columns]

# %% [markdown]
# ### Checking and cleaning Status -
# #### Dropping abandoned wells

# %%
prod_df.status.unique()
# Out:
# array(['FLOWING GAS', 'ABANDONED', 'ABANDONED GAS', 'OIL ABANDONED ZONE',
#        'ABANDONED, RE-ENTERED GAS', 'ABANDONED ZONE',
#        'ABANDONED GAS ZONE', 'ABANDONED AND WHIPSTOCKED GAS'],
#       dtype=object)

# %%
prod_df.status = prod_df.status.str.lower().str.replace(" ","_")

# %% [markdown]
# ##### Names of the well status

# %%
prod_df.status.unique()
# Out:
# array(['flowing_gas', 'abandoned', 'abandoned_gas', 'oil_abandoned_zone',
#        'abandoned,_re-entered_gas', 'abandoned_zone',
#        'abandoned_gas_zone', 'abandoned_and_whipstocked_gas'],
#       dtype=object)

# %%
prod_df.status = prod_df.status.replace("abandoned,_re-entered_gas", "abandoned_re-entered_gas")

# %% [markdown]
# ##### Cleaned Well Status names

# %%
prod_df.status.unique()
# Out:
# array(['flowing_gas', 'abandoned', 'abandoned_gas', 'oil_abandoned_zone',
#        'abandoned_re-entered_gas', 'abandoned_zone', 'abandoned_gas_zone',
#        'abandoned_and_whipstocked_gas'], dtype=object)

# %%
prod_df.head()
# Out:
#                     uwi prod_date       status monthly_oil_(bbl)  \
# 1  100/06-20-033-04W5/0  Jan-2000  flowing_gas              0.00
# 2  100/06-20-033-04W5/0  Feb-2000  flowing_gas              0.00
# 3  100/06-20-033-04W5/0  Mar-2000  flowing_gas              0.00
# 4  100/06-20-033-04W5/0  Apr-2000  flowing_gas              0.00
# 5  100/06-20-033-04W5/0  May-2000  flowing_gas              0.00
#
#   avg_dly_oil_(bbl/d) cal_dly_oil_(bbl/d) cum_prd_oil_(bbl) monthly_gas_(mcf)  \
# 1                0.00                0.00              0.00         724753.57
# 2                0.00                0.00              0.00         723603.57
# 3                0.00                0.00              0.00         743476.51
# 4                0.00                0.00              0.00         616675.16
# 5                0.00                0.00              0.00         739799.36
#
#   avg_dly_gas_(mcf/d) cal_dly_gas_(mcf/d)      ...       inj_hours_(hr)  \
# 1            23794.92            23379.15      ...                    0
# 2            25389.60            24951.85      ...                    0
# 3            24817.02            23983.11      ...                    0
# 4            24916.17            20555.84      ...                    0
# 5            24322.17            23864.50      ...                    0
#
#   prd_hours_(hr) inj/prd_hours_(hr) wct_(%) oct_(%) cct_(%) gor_(scf/bbl)  \
# 1            731                731  100.00    0.00    0.00          0.00
# 2            684                684  100.00    0.00    0.00          0.00
# 3            719                719  100.00    0.00    0.00          0.00
# 4            594                594  100.00    0.00    0.00          0.00
# 5            730                730  100.00    0.00    0.00          0.00
#
#   wgr_(bbl/mmcf) wor_(bbl/bbl) cgr_(bbl/mmcf)
# 1           3.14          0.00           0.00
# 2           2.93          0.00           0.00
# 3           2.98          0.00           0.00
# 4           2.99          0.00           0.00
# 5           3.07          0.00           0.00
#
# [5 rows x 49 columns]

# %%
abd_wells = prod_df.status[prod_df.status.str.contains("abandoned", regex = False)].unique().tolist()

# %% [markdown]
# #### All The abandoned well statuses

# %%
abd_wells
# Out:
# ['abandoned',
#  'abandoned_gas',
#  'oil_abandoned_zone',
#  'abandoned_re-entered_gas',
#  'abandoned_zone',
#  'abandoned_gas_zone',
#  'abandoned_and_whipstocked_gas']

# %%
prod_df[prod_df.status.isin(abd_wells)].status.unique()
# Out:
# array(['abandoned', 'abandoned_gas', 'oil_abandoned_zone',
#        'abandoned_re-entered_gas', 'abandoned_zone', 'abandoned_gas_zone',
#        'abandoned_and_whipstocked_gas'], dtype=object)

# %% [markdown]
# ##### Removing abandoned wells

# %%
abd_well_index = prod_df[~prod_df.status.isin(abd_wells)].index

# %%
prod_df = prod_df[~prod_df.status.isin(abd_wells)].reset_index()

# %%
prod_df.head()
# Out:
#    index                   uwi prod_date       status monthly_oil_(bbl)  \
# 0      1  100/06-20-033-04W5/0  Jan-2000  flowing_gas              0.00
# 1      2  100/06-20-033-04W5/0  Feb-2000  flowing_gas              0.00
# 2      3  100/06-20-033-04W5/0  Mar-2000  flowing_gas              0.00
# 3      4  100/06-20-033-04W5/0  Apr-2000  flowing_gas              0.00
# 4      5  100/06-20-033-04W5/0  May-2000  flowing_gas              0.00
#
#   avg_dly_oil_(bbl/d) cal_dly_oil_(bbl/d) cum_prd_oil_(bbl) monthly_gas_(mcf)  \
# 0                0.00                0.00              0.00         724753.57
# 1                0.00                0.00              0.00         723603.57
# 2                0.00                0.00              0.00         743476.51
# 3                0.00                0.00              0.00         616675.16
# 4                0.00                0.00              0.00         739799.36
#
#   avg_dly_gas_(mcf/d)      ...       inj_hours_(hr) prd_hours_(hr)  \
# 0            23794.92      ...                    0            731
# 1            25389.60      ...                    0            684
# 2            24817.02      ...                    0            719
# 3            24916.17      ...                    0            594
# 4            24322.17      ...                    0            730
#
#   inj/prd_hours_(hr) wct_(%) oct_(%) cct_(%) gor_(scf/bbl) wgr_(bbl/mmcf)  \
# 0                731  100.00    0.00    0.00          0.00           3.14
# 1                684  100.00    0.00    0.00          0.00           2.93
# 2                719  100.00    0.00    0.00          0.00           2.98
# 3                594  100.00    0.00    0.00          0.00           2.99
# 4                730  100.00    0.00    0.00          0.00           3.07
#
#   wor_(bbl/bbl) cgr_(bbl/mmcf)
# 0          0.00           0.00
# 1          0.00           0.00
# 2          0.00           0.00
# 3          0.00           0.00
# 4          0.00           0.00
#
# [5 rows x 50 columns]

# %% [markdown]
# ##### Only active and suspended wells left

# %%
prod_df.status.unique()
# Out:
# array(['flowing_gas'], dtype=object)

# %%
prod_df.shape
# Out:
# (2851, 50)

# %% [markdown]
# #### UWI analysis

# %%
uwis = prod_df.uwi.unique()

uwis
# Out:
# array(['100/06-20-033-04W5/0', '100/05-32-033-04W5/0',
#        '100/07-18-034-04W5/0', '100/09-24-034-05W5/0',
#        '100/06-35-034-05W5/0', '100/14-24-034-06W5/0',
#        '100/06-36-034-06W5/0', '102/06-02-035-05W5/0',
#        '100/03-10-035-05W5/0', '100/10-15-035-05W5/0',
#        '100/11-16-035-05W5/0', '100/07-28-035-05W5/2',
#        '100/12-01-035-06W5/0', '100/09-02-035-06W5/2'], dtype=object)

# %%
for uwi in uwis:
    print(prod_df[prod_df.uwi == uwi].head())
    prod_df.set_index('prod_date').groupby('uwi').rolling(window=1, freq='Y').mean()['cal_dly_oil_(bbl/d)','cum_prd_oil_(bbl)','cal_dly_gas_(mcf/d)','cum_prd_gas_(mcf)','cal_dly_water_(bbl/d)','cum_prd_water_(bbl)','cal_dly_cond_(bbl/d)','cum_prd_cond_(bbl)','prd_hours_(hr)']
# Out:
#    index                   uwi prod_date       status monthly_oil_(bbl)  \
# 0      1  100/06-20-033-04W5/0  Jan-2000  flowing_gas              0.00
# 1      2  100/06-20-033-04W5/0  Feb-2000  flowing_gas              0.00
# 2      3  100/06-20-033-04W5/0  Mar-2000  flowing_gas              0.00
# 3      4  100/06-20-033-04W5/0  Apr-2000  flowing_gas              0.00
# 4      5  100/06-20-033-04W5/0  May-2000  flowing_gas              0.00
#
#   avg_dly_oil_(bbl/d) cal_dly_oil_(bbl/d) cum_prd_oil_(bbl) monthly_gas_(mcf)  \
# 0                0.00                0.00              0.00         724753.57
# 1                0.00                0.00              0.00         723603.57
# 2                0.00                0.00              0.00         743476.51
# 3                0.00                0.00              0.00         616675.16
# 4                0.00                0.00              0.00         739799.36
#
#   avg_dly_gas_(mcf/d)      ...       inj_hours_(hr) prd_hours_(hr)  \
# 0            23794.92      ...                    0            731
# 1            25389.60      ...                    0            684
# 2            24817.02      ...                    0            719
# 3            24916.17      ...                    0            594
# 4            24322.17      ...                    0            730
#
#   inj/prd_hours_(hr) wct_(%) oct_(%) cct_(%) gor_(scf/bbl) wgr_(bbl/mmcf)  \
# 0                731  100.00    0.00    0.00          0.00           3.14
# 1                684  100.00    0.00    0.00          0.00           2.93
# 2                719  100.00    0.00    0.00          0.00           2.98
# 3                594  100.00    0.00    0.00          0.00           2.99
# 4                730  100.00    0.00    0.00          0.00           3.07
#
#   wor_(bbl/bbl) cgr_(bbl/mmcf)
# 0          0.00           0.00
# 1          0.00           0.00
# 2          0.00           0.00
# 3          0.00           0.00
# 4          0.00           0.00
#
# [5 rows x 50 columns]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Anaconda3\lib\site-packages\pandas\core\window.py in _prep_values(self, values, kill_inf)
#     221             try:
# --> 222                 values = _ensure_float64(values)
#     223             except (ValueError, TypeError):
#
# pandas\_libs\algos_common_helper.pxi in pandas._libs.algos.ensure_float64()
#
# pandas\_libs\algos_common_helper.pxi in pandas._libs.algos.ensure_float64()
#
# ValueError: could not convert string to float: 'flowing_gas'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# C:\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in apply(self, func, *args, **kwargs)
#     917             try:
# --> 918                 result = self._python_apply_general(f)
#     919             except Exception:
#
# C:\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in _python_apply_general(self, f)
#     935         keys, values, mutated = self.grouper.apply(f, self._selected_obj,
# --> 936                                                    self.axis)
#     937
#
# C:\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in apply(self, f, data, axis)
#    2272             group_axes = _get_axes(group)
# -> 2273             res = f(group)
#    2274             if not _is_indexed_like(res, group_axes):
#
# C:\Anaconda3\lib\site-packages\pandas\core\window.py in f(x, name, *args)
#     799             if isinstance(name, compat.string_types):
# --> 800                 return getattr(x, name)(*args, **kwargs)
#     801
#
# C:\Anaconda3\lib\site-packages\pandas\core\window.py in mean(self, *args, **kwargs)
#    1604         nv.validate_rolling_func('mean', args, kwargs)
# -> 1605         return super(Rolling, self).mean(*args, **kwargs)
#    1606
#
# C:\Anaconda3\lib\site-packages\pandas\core\window.py in mean(self, *args, **kwargs)
#    1057         nv.validate_window_func('mean', args, kwargs)
# -> 1058         return self._apply('roll_mean', 'mean', **kwargs)
#    1059
#
# C:\Anaconda3\lib\site-packages\pandas\core\window.py in _apply(self, func, name, window, center, check_minp, **kwargs)
#     843         for b in blocks:
# --> 844             values = self._prep_values(b.values)
#     845
#
# C:\Anaconda3\lib\site-packages\pandas\core\window.py in _prep_values(self, values, kill_inf)
#     224                 raise TypeError("cannot handle this type -> {0}"
# --> 225                                 "".format(values.dtype))
#     226
#
# TypeError: cannot handle this type -> object
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# C:\Anaconda3\lib\site-packages\pandas\core\window.py in _prep_values(self, values, kill_inf)
#     221             try:
# --> 222                 values = _ensure_float64(values)
#     223             except (ValueError, TypeError):
#
# pandas\_libs\algos_common_helper.pxi in pandas._libs.algos.ensure_float64()
#
# pandas\_libs\algos_common_helper.pxi in pandas._libs.algos.ensure_float64()
#
# ValueError: could not convert string to float: 'flowing_gas'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-206-e47cd41b49c6> in <module>
#       1 for uwi in uwis:
#       2     print(prod_df[prod_df.uwi == uwi].head())
# ----> 3     prod_df.set_index('prod_date').groupby('uwi').rolling(window=1, freq='Y').mean()['cal_dly_oil_(bbl/d)','cum_prd_oil_(bbl)','cal_dly_gas_(mcf/d)','cum_prd_gas_(mcf)','cal_dly_water_(bbl/d)','cum_prd_water_(bbl)','cal_dly_cond_(bbl/d)','cum_prd_cond_(bbl)','prd_hours_(hr)']
#
# C:\Anaconda3\lib\site-packages\pandas\core\window.py in mean(self, *args, **kwargs)
#    1603     def mean(self, *args, **kwargs):
#    1604         nv.validate_rolling_func('mean', args, kwargs)
# -> 1605         return super(Rolling, self).mean(*args, **kwargs)
#    1606
#    1607     @Substitution(name='rolling')
#
# C:\Anaconda3\lib\site-packages\pandas\core\window.py in mean(self, *args, **kwargs)
#    1056     def mean(self, *args, **kwargs):
#    1057         nv.validate_window_func('mean', args, kwargs)
# -> 1058         return self._apply('roll_mean', 'mean', **kwargs)
#    1059
#    1060     _shared_docs['median'] = dedent("""
#
# C:\Anaconda3\lib\site-packages\pandas\core\window.py in _apply(self, func, name, window, center, check_minp, **kwargs)
#     802             return x.apply(name, *args, **kwargs)
#     803
# --> 804         return self._groupby.apply(f)
#     805
#     806
#
# C:\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in apply(self, func, *args, **kwargs)
#     928
#     929                 with _group_selection_context(self):
# --> 930                     return self._python_apply_general(f)
#     931
#     932         return result
#
# C:\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in _python_apply_general(self, f)
#     934     def _python_apply_general(self, f):
#     935         keys, values, mutated = self.grouper.apply(f, self._selected_obj,
# --> 936                                                    self.axis)
#     937
#     938         return self._wrap_applied_output(
#
# C:\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in apply(self, f, data, axis)
#    2271             # group might be modified
#    2272             group_axes = _get_axes(group)
# -> 2273             res = f(group)
#    2274             if not _is_indexed_like(res, group_axes):
#    2275                 mutated = True
#
# C:\Anaconda3\lib\site-packages\pandas\core\window.py in f(x, name, *args)
#     798
#     799             if isinstance(name, compat.string_types):
# --> 800                 return getattr(x, name)(*args, **kwargs)
#     801
#     802             return x.apply(name, *args, **kwargs)
#
# C:\Anaconda3\lib\site-packages\pandas\core\window.py in mean(self, *args, **kwargs)
#    1603     def mean(self, *args, **kwargs):
#    1604         nv.validate_rolling_func('mean', args, kwargs)
# -> 1605         return super(Rolling, self).mean(*args, **kwargs)
#    1606
#    1607     @Substitution(name='rolling')
#
# C:\Anaconda3\lib\site-packages\pandas\core\window.py in mean(self, *args, **kwargs)
#    1056     def mean(self, *args, **kwargs):
#    1057         nv.validate_window_func('mean', args, kwargs)
# -> 1058         return self._apply('roll_mean', 'mean', **kwargs)
#    1059
#    1060     _shared_docs['median'] = dedent("""
#
# C:\Anaconda3\lib\site-packages\pandas\core\window.py in _apply(self, func, name, window, center, check_minp, **kwargs)
#     842         results = []
#     843         for b in blocks:
# --> 844             values = self._prep_values(b.values)
#     845
#     846             if values.size == 0:
#
# C:\Anaconda3\lib\site-packages\pandas\core\window.py in _prep_values(self, values, kill_inf)
#     223             except (ValueError, TypeError):
#     224                 raise TypeError("cannot handle this type -> {0}"
# --> 225                                 "".format(values.dtype))
#     226
#     227         if kill_inf:
#
# TypeError: cannot handle this type -> object

# %%
prod_df.columns.tolist()
# Out:
# ['index',
#  'uwi',
#  'prod_date',
#  'status',
#  'monthly_oil_(bbl)',
#  'avg_dly_oil_(bbl/d)',
#  'cal_dly_oil_(bbl/d)',
#  'cum_prd_oil_(bbl)',
#  'monthly_gas_(mcf)',
#  'avg_dly_gas_(mcf/d)',
#  'cal_dly_gas_(mcf/d)',
#  'cum_prd_gas_(mcf)',
#  'monthly_water_(bbl)',
#  'avg_dly_water_(bbl/d)',
#  'cal_dly_water_(bbl/d)',
#  'cum_prd_water_(bbl)',
#  'monthly_cond_(bbl)',
#  'avg_dly_cond_(bbl/d)',
#  'cal_dly_cond_(bbl/d)',
#  'cum_prd_cond_(bbl)',
#  'monthly_fluid_(bbl)',
#  'avg_dly_fluid_(bbl/d)',
#  'cal_dly_fluid_(bbl/d)',
#  'cum_prd_fluid_(bbl)',
#  'mon_inj_oil_(bbl)',
#  'avg_inj_oil_(bbl/d)',
#  'cal_inj_oil_(bbl/d)',
#  'cum_inj_oil_(bbl)',
#  'mon_inj_gas_(mcf)',
#  'avg_inj_gas_(mcf/d)',
#  'cal_inj_gas_(mcf/d)',
#  'cum_inj_gas_(mcf)',
#  'mon_inj_water_(bbl)',
#  'avg_inj_water_(bbl/d)',
#  'cal_inj_water_(bbl/d)',
#  'cum_inj_water_(bbl)',
#  'mon_inj_solv_(mcf)',
#  'avg_inj_solv_(mcf/d)',
#  'cal_inj_solv_(mcf/d)',
#  'cum_inj_solv_(mcf)',
#  'inj_hours_(hr)',
#  'prd_hours_(hr)',
#  'inj/prd_hours_(hr)',
#  'wct_(%)',
#  'oct_(%)',
#  'cct_(%)',
#  'gor_(scf/bbl)',
#  'wgr_(bbl/mmcf)',
#  'wor_(bbl/bbl)',
#  'cgr_(bbl/mmcf)']

# %%
(prod_df.set_index('prod_date').groupby('uwi').rolling(window=1, freq='Y').mean()
 [['cal_dly_oil_(bbl/d)','cum_prd_oil_(bbl)','cal_dly_gas_(mcf/d)','cum_prd_gas_(mcf)',
  'cal_dly_water_(bbl/d)','cum_prd_water_(bbl)','cal_dly_cond_(bbl/d)','cum_prd_cond_(bbl)','prd_hours_(hr)']])
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Anaconda3\lib\site-packages\pandas\core\window.py in _prep_values(self, values, kill_inf)
#     221             try:
# --> 222                 values = _ensure_float64(values)
#     223             except (ValueError, TypeError):
#
# pandas\_libs\algos_common_helper.pxi in pandas._libs.algos.ensure_float64()
#
# pandas\_libs\algos_common_helper.pxi in pandas._libs.algos.ensure_float64()
#
# ValueError: could not convert string to float: 'flowing_gas'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# C:\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in apply(self, func, *args, **kwargs)
#     917             try:
# --> 918                 result = self._python_apply_general(f)
#     919             except Exception:
#
# C:\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in _python_apply_general(self, f)
#     935         keys, values, mutated = self.grouper.apply(f, self._selected_obj,
# --> 936                                                    self.axis)
#     937
#
# C:\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in apply(self, f, data, axis)
#    2272             group_axes = _get_axes(group)
# -> 2273             res = f(group)
#    2274             if not _is_indexed_like(res, group_axes):
#
# C:\Anaconda3\lib\site-packages\pandas\core\window.py in f(x, name, *args)
#     799             if isinstance(name, compat.string_types):
# --> 800                 return getattr(x, name)(*args, **kwargs)
#     801
#
# C:\Anaconda3\lib\site-packages\pandas\core\window.py in mean(self, *args, **kwargs)
#    1604         nv.validate_rolling_func('mean', args, kwargs)
# -> 1605         return super(Rolling, self).mean(*args, **kwargs)
#    1606
#
# C:\Anaconda3\lib\site-packages\pandas\core\window.py in mean(self, *args, **kwargs)
#    1057         nv.validate_window_func('mean', args, kwargs)
# -> 1058         return self._apply('roll_mean', 'mean', **kwargs)
#    1059
#
# C:\Anaconda3\lib\site-packages\pandas\core\window.py in _apply(self, func, name, window, center, check_minp, **kwargs)
#     843         for b in blocks:
# --> 844             values = self._prep_values(b.values)
#     845
#
# C:\Anaconda3\lib\site-packages\pandas\core\window.py in _prep_values(self, values, kill_inf)
#     224                 raise TypeError("cannot handle this type -> {0}"
# --> 225                                 "".format(values.dtype))
#     226
#
# TypeError: cannot handle this type -> object
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# C:\Anaconda3\lib\site-packages\pandas\core\window.py in _prep_values(self, values, kill_inf)
#     221             try:
# --> 222                 values = _ensure_float64(values)
#     223             except (ValueError, TypeError):
#
# pandas\_libs\algos_common_helper.pxi in pandas._libs.algos.ensure_float64()
#
# pandas\_libs\algos_common_helper.pxi in pandas._libs.algos.ensure_float64()
#
# ValueError: could not convert string to float: 'flowing_gas'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-210-e1cbf688a462> in <module>
# ----> 1 (prod_df.ix[1:].set_index('prod_date').groupby('uwi').rolling(window=1, freq='Y').mean()
#       2  [['cal_dly_oil_(bbl/d)','cum_prd_oil_(bbl)','cal_dly_gas_(mcf/d)','cum_prd_gas_(mcf)',
#       3   'cal_dly_water_(bbl/d)','cum_prd_water_(bbl)','cal_dly_cond_(bbl/d)','cum_prd_cond_(bbl)','prd_hours_(hr)']])
#
# C:\Anaconda3\lib\site-packages\pandas\core\window.py in mean(self, *args, **kwargs)
#    1603     def mean(self, *args, **kwargs):
#    1604         nv.validate_rolling_func('mean', args, kwargs)
# -> 1605         return super(Rolling, self).mean(*args, **kwargs)
#    1606
#    1607     @Substitution(name='rolling')
#
# C:\Anaconda3\lib\site-packages\pandas\core\window.py in mean(self, *args, **kwargs)
#    1056     def mean(self, *args, **kwargs):
#    1057         nv.validate_window_func('mean', args, kwargs)
# -> 1058         return self._apply('roll_mean', 'mean', **kwargs)
#    1059
#    1060     _shared_docs['median'] = dedent("""
#
# C:\Anaconda3\lib\site-packages\pandas\core\window.py in _apply(self, func, name, window, center, check_minp, **kwargs)
#     802             return x.apply(name, *args, **kwargs)
#     803
# --> 804         return self._groupby.apply(f)
#     805
#     806
#
# C:\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in apply(self, func, *args, **kwargs)
#     928
#     929                 with _group_selection_context(self):
# --> 930                     return self._python_apply_general(f)
#     931
#     932         return result
#
# C:\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in _python_apply_general(self, f)
#     934     def _python_apply_general(self, f):
#     935         keys, values, mutated = self.grouper.apply(f, self._selected_obj,
# --> 936                                                    self.axis)
#     937
#     938         return self._wrap_applied_output(
#
# C:\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in apply(self, f, data, axis)
#    2271             # group might be modified
#    2272             group_axes = _get_axes(group)
# -> 2273             res = f(group)
#    2274             if not _is_indexed_like(res, group_axes):
#    2275                 mutated = True
#
# C:\Anaconda3\lib\site-packages\pandas\core\window.py in f(x, name, *args)
#     798
#     799             if isinstance(name, compat.string_types):
# --> 800                 return getattr(x, name)(*args, **kwargs)
#     801
#     802             return x.apply(name, *args, **kwargs)
#
# C:\Anaconda3\lib\site-packages\pandas\core\window.py in mean(self, *args, **kwargs)
#    1603     def mean(self, *args, **kwargs):
#    1604         nv.validate_rolling_func('mean', args, kwargs)
# -> 1605         return super(Rolling, self).mean(*args, **kwargs)
#    1606
#    1607     @Substitution(name='rolling')
#
# C:\Anaconda3\lib\site-packages\pandas\core\window.py in mean(self, *args, **kwargs)
#    1056     def mean(self, *args, **kwargs):
#    1057         nv.validate_window_func('mean', args, kwargs)
# -> 1058         return self._apply('roll_mean', 'mean', **kwargs)
#    1059
#    1060     _shared_docs['median'] = dedent("""
#
# C:\Anaconda3\lib\site-packages\pandas\core\window.py in _apply(self, func, name, window, center, check_minp, **kwargs)
#     842         results = []
#     843         for b in blocks:
# --> 844             values = self._prep_values(b.values)
#     845
#     846             if values.size == 0:
#
# C:\Anaconda3\lib\site-packages\pandas\core\window.py in _prep_values(self, values, kill_inf)
#     223             except (ValueError, TypeError):
#     224                 raise TypeError("cannot handle this type -> {0}"
# --> 225                                 "".format(values.dtype))
#     226
#     227         if kill_inf:
#
# TypeError: cannot handle this type -> object

# %%
prod_df.set_index('prod_date').groupby(["uwi", 'status']).rolling(window =1, freq = 'M').mean()[['cal_dly_oil_(bbl/d)','cum_prd_oil_(bbl)','cal_dly_gas_(mcf/d)','cum_prd_gas_(mcf)',
  'cal_dly_water_(bbl/d)','cum_prd_water_(bbl)','cal_dly_cond_(bbl/d)','cum_prd_cond_(bbl)','prd_hours_(hr)']]
# Out:
#                                             cal_dly_oil_(bbl/d)  \
# uwi                  status      prod_date
# 100/03-10-035-05W5/0 flowing_gas Jan-2000                   0.0
#                                  Feb-2000                   0.0
#                                  Mar-2000                   0.0
#                                  Apr-2000                   0.0
#                                  May-2000                   0.0
#                                  Jun-2000                   0.0
#                                  Jul-2000                   0.0
#                                  Aug-2000                   0.0
#                                  Sep-2000                   0.0
#                                  Oct-2000                   0.0
#                                  Nov-2000                   0.0
#                                  Dec-2000                   0.0
#                                  Jan-2001                   0.0
#                                  Feb-2001                   0.0
#                                  Mar-2001                   0.0
#                                  Apr-2001                   0.0
#                                  May-2001                   0.0
#                                  Jun-2001                   0.0
#                                  Jul-2001                   0.0
#                                  Aug-2001                   0.0
#                                  Sep-2001                   0.0
#                                  Oct-2001                   0.0
#                                  Nov-2001                   0.0
#                                  Dec-2001                   0.0
#                                  Jan-2002                   0.0
#                                  Feb-2002                   0.0
#                                  Mar-2002                   0.0
#                                  Apr-2002                   0.0
#                                  May-2002                   0.0
#                                  Jun-2002                   0.0
# ...                                                         ...
# 102/06-02-035-05W5/0 flowing_gas Sep-2015                   0.0
#                                  Oct-2015                   0.0
#                                  Nov-2015                   0.0
#                                  Dec-2015                   0.0
#                                  Jan-2016                   0.0
#                                  Feb-2016                   0.0
#                                  Mar-2016                   0.0
#                                  Apr-2016                   0.0
#                                  May-2016                   0.0
#                                  Jun-2016                   0.0
#                                  Jul-2016                   0.0
#                                  Aug-2016                   0.0
#                                  Sep-2016                   0.0
#                                  Oct-2016                   0.0
#                                  Nov-2016                   0.0
#                                  Dec-2016                   0.0
#                                  Jan-2017                   0.0
#                                  Feb-2017                   0.0
#                                  Mar-2017                   0.0
#                                  Apr-2017                   0.0
#                                  May-2017                   0.0
#                                  Jun-2017                   0.0
#                                  Jul-2017                   0.0
#                                  Aug-2017                   0.0
#                                  Sep-2017                   0.0
#                                  Oct-2017                   0.0
#                                  Nov-2017                   0.0
#                                  Dec-2017                   0.0
#                                  Jan-2018                   0.0
#                                  Feb-2018                   0.0
#
#                                             cum_prd_oil_(bbl)  \
# uwi                  status      prod_date
# 100/03-10-035-05W5/0 flowing_gas Jan-2000                 0.0
#                                  Feb-2000                 0.0
#                                  Mar-2000                 0.0
#                                  Apr-2000                 0.0
#                                  May-2000                 0.0
#                                  Jun-2000                 0.0
#                                  Jul-2000                 0.0
#                                  Aug-2000                 0.0
#                                  Sep-2000                 0.0
#                                  Oct-2000                 0.0
#                                  Nov-2000                 0.0
#                                  Dec-2000                 0.0
#                                  Jan-2001                 0.0
#                                  Feb-2001                 0.0
#                                  Mar-2001                 0.0
#                                  Apr-2001                 0.0
#                                  May-2001                 0.0
#                                  Jun-2001                 0.0
#                                  Jul-2001                 0.0
#                                  Aug-2001                 0.0
#                                  Sep-2001                 0.0
#                                  Oct-2001                 0.0
#                                  Nov-2001                 0.0
#                                  Dec-2001                 0.0
#                                  Jan-2002                 0.0
#                                  Feb-2002                 0.0
#                                  Mar-2002                 0.0
#                                  Apr-2002                 0.0
#                                  May-2002                 0.0
#                                  Jun-2002                 0.0
# ...                                                       ...
# 102/06-02-035-05W5/0 flowing_gas Sep-2015                 0.0
#                                  Oct-2015                 0.0
#                                  Nov-2015                 0.0
#                                  Dec-2015                 0.0
#                                  Jan-2016                 0.0
#                                  Feb-2016                 0.0
#                                  Mar-2016                 0.0
#                                  Apr-2016                 0.0
#                                  May-2016                 0.0
#                                  Jun-2016                 0.0
#                                  Jul-2016                 0.0
#                                  Aug-2016                 0.0
#                                  Sep-2016                 0.0
#                                  Oct-2016                 0.0
#                                  Nov-2016                 0.0
#                                  Dec-2016                 0.0
#                                  Jan-2017                 0.0
#                                  Feb-2017                 0.0
#                                  Mar-2017                 0.0
#                                  Apr-2017                 0.0
#                                  May-2017                 0.0
#                                  Jun-2017                 0.0
#                                  Jul-2017                 0.0
#                                  Aug-2017                 0.0
#                                  Sep-2017                 0.0
#                                  Oct-2017                 0.0
#                                  Nov-2017                 0.0
#                                  Dec-2017                 0.0
#                                  Jan-2018                 0.0
#                                  Feb-2018                 0.0
#
#                                             cal_dly_gas_(mcf/d)  \
# uwi                  status      prod_date
# 100/03-10-035-05W5/0 flowing_gas Jan-2000                  0.00
#                                  Feb-2000                  0.00
#                                  Mar-2000                  0.00
#                                  Apr-2000                  0.00
#                                  May-2000                  0.00
#                                  Jun-2000                  0.00
#                                  Jul-2000                  0.00
#                                  Aug-2000                  0.00
#                                  Sep-2000                  0.00
#                                  Oct-2000                  0.00
#                                  Nov-2000                  0.00
#                                  Dec-2000                  0.00
#                                  Jan-2001                  0.00
#                                  Feb-2001                  0.00
#                                  Mar-2001                  0.00
#                                  Apr-2001                  0.00
#                                  May-2001                  0.00
#                                  Jun-2001                  0.00
#                                  Jul-2001                  0.00
#                                  Aug-2001                  0.00
#                                  Sep-2001                  0.00
#                                  Oct-2001                  0.00
#                                  Sep-2016                    0.0
#                                  Oct-2016                    0.0
#                                  Nov-2016                    0.0
#                                  Dec-2016                    0.0
#                                  Jan-2017                    0.0
#                                  Feb-2017                    0.0
#                                  Mar-2017                    0.0
#                                  Apr-2017                    0.0
#                                  May-2017                    0.0
#                                  Jun-2017                    0.0
#                                  Jul-2017                    0.0
#                                  Aug-2017                    0.0
#                                  Sep-2017                    0.0
#                                  Oct-2017                    0.0
#                                  Nov-2017                    0.0
#                                  Dec-2017                    0.0
#                                  Jan-2018                    0.0
#                                  Feb-2018                    0.0
#
#                                             cum_prd_cond_(bbl)  prd_hours_(hr)
# uwi                  status      prod_date
# 100/03-10-035-05W5/0 flowing_gas Jan-2000                 0.00             0.0
#                                  Feb-2000                 0.00             0.0
#                                  Mar-2000                 0.00             0.0
#                                  Apr-2000                 0.00             0.0
#                                  May-2000                 0.00             0.0
#                                  Jun-2000                 0.00             0.0
#                                  Jul-2000                 0.00             0.0
#                                  Aug-2000                 0.00             0.0
#                                  Sep-2000                 0.00             0.0
#                                  Oct-2000                 0.00             0.0
#                                  Nov-2000                 0.00             0.0
#                                  Dec-2000                 0.00             0.0
#                                  Jan-2001                 0.00             0.0
#                                  Feb-2001                 0.00             0.0
#                                  Mar-2001                 0.00             0.0
#                                  Apr-2001                 0.00             0.0
#                                  May-2001                 0.00             0.0
#                                  Jun-2001                 0.00             0.0
#                                  Jul-2001                 0.00             0.0
#                                  Aug-2001                 0.00             0.0
#                                  Sep-2001                 0.00             0.0
#                                  Oct-2001                 0.00             0.0
#                                  Nov-2001                 0.00             0.0
#                                  Dec-2001                 0.00             0.0
#                                  Jan-2002                 0.00             0.0
#                                  Feb-2002                 0.00             0.0
#                                  Mar-2002                 0.00             0.0
#                                  Apr-2002                 0.00             0.0
#                                  May-2002                 0.00             0.0
#                                  Jun-2002                 0.00             0.0
# ...                                                        ...             ...
# 102/06-02-035-05W5/0 flowing_gas Sep-2015                16.99           720.0
#                                  Oct-2015                16.99           744.0
#                                  Nov-2015                16.99           720.0
#                                  Dec-2015                16.99           743.0
#                                  Jan-2016                16.99           743.0
#                                  Feb-2016                16.99           695.0
#                                  Mar-2016                16.99           743.0
#                                  Apr-2016                16.99           720.0
#                                  May-2016                16.99           742.0
#                                  Jun-2016                16.99           719.0
#                                  Jul-2016                16.99           744.0
#                                  Aug-2016                16.99           738.0
#                                  Sep-2016                16.99           715.0
#                                  Oct-2016                16.99           737.0
#                                  Nov-2016                16.99           720.0
#                                  Dec-2016                16.99           743.0
#                                  Jan-2017                16.99           744.0
#                                  Feb-2017                16.99           672.0
#                                  Mar-2017                16.99           743.0
#                                  Apr-2017                16.99           720.0
#                                  May-2017                16.99           740.0
#                                  Jun-2017                16.99           719.0
#                                  Jul-2017                16.99           744.0
#                                  Aug-2017                16.99           744.0
#                                  Sep-2017                16.99           720.0
#                                  Oct-2017                16.99           743.0
#                                  Nov-2017                16.99           720.0
#                                  Dec-2017                16.99           739.0
#                                  Jan-2018                16.99           736.0
#                                  Feb-2018                16.99           672.0
#
# [2851 rows x 9 columns]
